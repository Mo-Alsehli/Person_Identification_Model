# %%
import tensorflow as tf
import os
import cv2

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
read_directory_path = "newDir/"
write_directory_path = "newDir/faces"
i = 0
# Loop through all files in the directory
for filename in os.listdir(read_directory_path):
    if filename.endswith(('.jpg', '.jpeg', '.png')):  # Check if the file is an image
        # Construct the full file path
        file_path = os.path.join(read_directory_path, filename)

        # Read the image using OpenCV
        img = cv2.imread(file_path)
    imgGray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # For detecting if there are multiple eyes
    face = faceCascade.detectMultiScale(imgGray, 1.1, 4)
    print(face)
    for x, y, w, h in face:
        roi_gray = imgGray[y:y+h, x: x+w]
        roi_color = img[y:y+h, x:x+w]
        faces = faceCascade.detectMultiScale(roi_gray)
        print(len(faces))
        if len(faces) == 0:
            print("Face is not detected")
        else:
            for(ex, ey, ew, eh) in faces:
                face_roi = roi_color[ey: ey+eh, ex:ex+ew]
                write_directory_path = f"newDir/faces/face_roi{i}.jpg"
                cv2.imwrite(write_directory_path, face_roi)
    
    i += 1
# Out:
# [[ 74  72 211 211]]
# 0
# Face is not detected
# [[ 60  59 211 211]]
# 1
# [[700 111 340 340]
#  [128 671  93  93]]
# 1
# 0
# Face is not detected
# [[ 653  124  358  358]
#  [1443  567  132  132]
#  [ 682  757   66   66]]
# 1
# 0
# Face is not detected
# 0
# Face is not detected
# [[693 107 354 354]]
# 1
# [[139 638  89  89]
#  [730  77 333 333]
#  [393 519  57  57]]
# 1
# 1
# 0
# Face is not detected
# [[704 104 355 355]
#  [317 615  80  80]]
# 1
# 0
# Face is not detected
# [[ 121 1003   51   51]]
# 0
# Face is not detected
# [[ 661  109  359  359]
#  [1766  222   55   55]
#  [ 378  682   53   53]]
# 1
# 0
# Face is not detected
# 0
# Face is not detected
# [[160 421  38  38]
#  [669 116 330 330]
#  [163 468  34  34]
#  [374 672  58  58]]
# 0
# Face is not detected
# 0
# Face is not detected
# 0
# Face is not detected
# 0
# Face is not detected
# [[ 671   96  371  371]
#  [ 379  675   55   55]
#  [1769  231   59   59]]
# 1
# 0
# Face is not detected
# 1
# [[669 114 354 354]]
# 1
# ...
